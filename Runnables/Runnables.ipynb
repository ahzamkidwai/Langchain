# %%
import random

class NakliLLM:
  def __init__(self):
    print("LLM Created")

  def predict(self, prompt):
    response_list=[
        'Delhi is the capital city of India',
        'IPL is a cricket league.',
        'AI stands for Artificial Intelligence'
    ]
    return { 'response': random.choice(response_list)}

# %%
class NakliPromptTemplate:
  def __init__(self, template, input_variables):
    self.template = template
    self.input_variables = input_variables
    print('Template is : ', template)
    print('Input Variables is : ', input_variables)
    print('Constructor is working')

  def format(self, input_dict):
    return self.template.format(**input_dict)

# %%
template = NakliPromptTemplate(
    template='Write a {length} poem about a topic {topic}',
    input_variables=['length', 'topic']
)
# Out:
# Template is :  Write a {length} poem about a topic {topic}
# Input Variables is :  ['length', 'topic']
# Constructor is working

# %%
prompt = template.format({'length':'short', 'topic':'India'})

# %%
llm = NakliLLM()
# Out:
# LLM Created

# %%
print("Prompt : ", prompt)
llm.predict(prompt)
# Out:
# Prompt :  Write a short poem about a topic India
# {'response': 'IPL is a cricket league.'}

# %%
class NakliLLMChain:
  def __init__(self, llm, prompt):
    self.llm=llm
    self.prompt=prompt
    print("Constructor is called")

  def run(self, input_dict):
    final_prompt = self.prompt.format(input_dict)
    result = self.llm.predict(final_prompt)
    return result['response']

# %%
template = NakliPromptTemplate(
    template='Write a {length} poem about a topic {topic}',
    input_variables=['length', 'topic']
)
# Out:
# Template is :  Write a {length} poem about a topic {topic}
# Input Variables is :  ['length', 'topic']
# Constructor is working

# %%
llm = NakliLLM()
# Out:
# LLM Created

# %%
chain = NakliLLMChain(llm, template)
# Out:
# Constructor is called

# %%
result = chain.run({'length':'short', 'topic':'India'})
print("Result is : ", result)
# Out:
# Result is :  AI stands for Artificial Intelligence
